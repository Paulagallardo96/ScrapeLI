# %%
from splinter import Browser
from bs4 import BeautifulSoup

import pandas as pd

# %%
executable_path = {'executable_path': './chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL of page to be scraped
url = 'https://www.linkedin.com/sales/search/people?savedSearchId=274884636&searchSessionId=7Jkr5RLjS66MboylCLh6Ww%3D%3D'
browser.visit(url)

# %%
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# %%
news_title =  soup.find('div', class_='content_title').a.text
news_p = soup.find('div', class_='article_teaser_body').text

print(news_title)
print(news_p)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="artdeco osx" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Sales Navigator
#   </title>
#   <meta content="" name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="%7B%22alternativeId%22%3A%22originalId%22%2C%22modulePrefix%22%3A%22lighthouse-web%22%2C%22environment%22%3A%22production%22%2C%22rootURL%22%3A%22/%22%2C%22locationType%22%3A%22router-scroll%22%2C%22historySupportMiddleware%22%3Atrue%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22EXTEND_PROTOTYPES%22%3A%7B%22Date%22%3Afalse%7D%7D%2C%22APP%22%3A%7B%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22/li/track%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%7D%2C%22name%22%3A%22lighthouse-web%22%2C%22version%22%3A%22lighthouse-web_0.2.505+b833286f%22%7D%2C%22eyeglass%22%3A%7B%22cssDir%22%3A%22assets%22%2C%22relativeAssets%22%3Afalse%7D%2C%22changeTracker%22%3A%7B%22auto%22%3Afalse%2C%22trackHasMany%22%3Afalse%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%27none%27%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%27self%27%20*.licdn.com%20*.licdn-ei.com%22%2C%22font-src%22%3A%22%27self%27%20*.licdn.com%20*.licdn-ei.com%22%2C%22connect-src%22%3A%22%27self%27%20localhost%3A*%22%2C%22img-src%22%3A%22%27self%27%20*.licdn.com%20*.licdn-ei.com%22%2C%22style-src%22%3A%22%27self%27%20%27unsafe-inline%27%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%27self%27%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22appId%22%3A%22com.linkedin.sales2.d_web%22%2C%22topicPrefix%22%3A%22%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22desktop%22%7D%2C%22comScore%22%3A%7B%22enabled%22%3Afalse%7D%7D%2C%22lix%22%3A%7B%22tests%22%3A%5B%22lss-grandfather-pro-crm-sync%22%2C%22lss-admin-crm-sync%22%2C%22lss-sso-idp%22%2C%22lss-notification-center%22%2C%22lss-inbox-attachment%22%2C%22lss-ep-integration%22%2C%22lss-inbox-assistant%22%2C%22lss-inbox-archive-mark-as-read%22%2C%22lss-vector-attachment%22%2C%22lss-productivity-dealbook%22%2C%22lss-productivity-dealspace%22%2C%22lss-productivity-fieldvalidation%22%2C%22lss-productivity-quickfilter%22%2C%22lss-company-orion%22%2C%22lss-profile-dossier%22%2C%22lss-out-of-inbox-overlay%22%2C%22lss-search-frank%22%2C%22lss-search-all-employee-new-entrypoint%22%2C%22lss-search-exclusions%22%2C%22lss-keyword-typeahead%22%2C%22lss-reports-to%22%2C%22lss-reports-to-typeahead%22%2C%22lss-account-center%22%2C%22profile-decoration.fetch.sales.navigator.info.for.contract%22%2C%22lss-project-negative%22%2C%22lss-admin-settings-crm-stat%22%2C%22lss-enable-admin-settings-crm-purge%22%2C%22lss-admin-settings-crm-sync-calls%22%2C%22lss-admin-settings-roi%22%2C%22lss-admin-settings-sso-csv%22%2C%22lss-crm-dynamics%22%2C%22lss-crm-writeback-presentation-view%22%2C%22lss-ads-integration%22%2C%22lss-enterprise-primary-identity%22%2C%22lss-seat-transfer%22%2C%22lss-seat-transfer-cancel%22%2C%22lss-crm-data-validation%22%2C%22lss-snap-crm-message%22%2C%22lss-crm-access-override%22%2C%22lss-snap-custom-lists%22%2C%22lss-lists-ranger%22%2C%22lss-lists-sharing%22%2C%22lss-desktop-internal-feedback%22%2C%22lss-crm-sync-error-handling%22%2C%22lss-nav-chrome-admin-crm-sync-flag%22%2C%22lss-user-completion-meter%22%2C%22lss-user-completion-meter-progress%22%2C%22lss-enable-onboarding%22%2C%22lss-relationship-strength-account%22%5D%7D%2C%22ember-cli-mirage%22%3A%7B%22enabled%22%3Afalse%2C%22directory%22%3A%22mirage%22%2C%22usingProxy%22%3Afalse%2C%22useDefaultPassthroughs%22%3Atrue%7D%2C%22contentSecurityPolicyHeader%22%3A%22Content-Security-Policy-Report-Only%22%2C%22exportApplicationGlobal%22%3Afalse%2C%22appVersion%22%3A%220.2.*%22%2C%22ember-collapsible-panel%22%3A%7B%7D%7D" name="lighthouse-web/config/environment"/>
#   <link href="https://static.licdn.com/sc/h/8cid09dn4abwh9sygrmp48elf" id="favicon-ico" rel="shortcut icon"/>
#   <link href="https://static.licdn.com/sc/h/3w39iyg1mpqyl92x6w8hks3l" rel="apple-touch-icon"/>
#   <link href="https://static.licdn.com/sc/h/bcssjypnzzvcuv91woopiackr" rel="apple-touch-icon-precomposed"/>
#   <link href="https://static.licdn.com/sc/h/ex80ountgx6vpj28b7ghe39bw" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="https://static.licdn.com/sc/h/1uls7lnzcc4o1kw0nspe2spdc" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="https://static.licdn.com/sc/h/br/3jfqe5rhmnmyn7ckcgcjv0egd" rel="stylesheet"/>
#   <link href="https://static.licdn.com/sc/h/br/3n5kwa8odq4x6cyijbd0n4hlq" rel="stylesheet"/>
#   <meta content="{}" name="spark/hash-includes"/>
#   <meta content="en_US" name="i18nDefaultLocale"/>
#   <meta content="en_US" name="i18nLocale"/>
#   <meta content="https://static.licdn.com/sc/h/br/1u9eqd3bjsa99o991kz809qq6" name="i18nIntlPolyfillUrl"/>
#   <meta content="us" name="requestIpCountryCode"/>
#   <meta content="urn:li:page:bpr;rd0w1zZcRKKdrLfbsn2sbg==" name="bprPageInstance"/>
#   <meta content='{"applicationUrn": "urn:li:application:(lighthouse-web,lighthouse-web)", "version": "0.2.505", "trackingId": [66, 8, -29, 47, -128, 84, 76, -23, -74, -73, -64, -124, 121, 2, 38, -118]}' name="applicationInstance"/>
#   <meta content="LIJmmYwsT9y7e2A9HV371A==" name="clientPageInstanceId"/>
#   <meta content="lighthouse-web" name="service"/>
#   <meta content="i001" name="serviceInstance"/>
#   <meta content="0.2.505" name="serviceVersion"/>
#   <meta content='{"lix":{"lss-crm-sync-error-handling":{"treatment":"control","testKey":"lss-crm-sync-error-handling","trackingInfo":null},"lss-seat-transfer":{"treatment":"enabled","testKey":"lss-seat-transfer","trackingInfo":null},"lss-crm-data-validation":{"treatment":"control","testKey":"lss-crm-data-validation","trackingInfo":null},"lss-user-completion-meter-progress":{"treatment":"control","testKey":"lss-user-completion-meter-progress","trackingInfo":null},"lss-admin-settings-crm-stat":{"treatment":"enabled","testKey":"lss-admin-settings-crm-stat","trackingInfo":null},"lss-ads-integration":{"treatment":"control","testKey":"lss-ads-integration","trackingInfo":null},"lss-snap-crm-message":{"treatment":"control","testKey":"lss-snap-crm-message","trackingInfo":null},"lss-productivity-dealbook":{"treatment":"enabled","testKey":"lss-productivity-dealbook","trackingInfo":null},"lss-enable-onboarding":{"treatment":"control","testKey":"lss-enable-onboarding","trackingInfo":null},"lss-admin-settings-sso-csv":{"treatment":"enabled","testKey":"lss-admin-settings-sso-csv","trackingInfo":null},"lss-admin-settings-roi":{"treatment":"enabled","testKey":"lss-admin-settings-roi","trackingInfo":null},"lss-vector-attachment":{"treatment":"enabled","testKey":"lss-vector-attachment","trackingInfo":null},"lss-relationship-strength-account":{"treatment":"control","testKey":"lss-relationship-strength-account","trackingInfo":null},"lss-seat-transfer-cancel":{"treatment":"enabled","testKey":"lss-seat-transfer-cancel","trackingInfo":null},"lss-desktop-internal-feedback":{"treatment":"control","testKey":"lss-desktop-internal-feedback","trackingInfo":null},"lss-productivity-quickfilter":{"treatment":"control","testKey":"lss-productivity-quickfilter","trackingInfo":null},"profile-decoration.fetch.sales.navigator.info.for.contract":{"treatment":"enable","testKey":"profile-decoration.fetch.sales.navigator.info.for.contract","trackingInfo":null},"lss-nav-chrome-admin-crm-sync-flag":{"treatment":"control","testKey":"lss-nav-chrome-admin-crm-sync-flag","trackingInfo":null},"lss-crm-dynamics":{"treatment":"enabled","testKey":"lss-crm-dynamics","trackingInfo":null},"lss-project-negative":{"treatment":"enabled","testKey":"lss-project-negative","trackingInfo":null},"lss-search-all-employee-new-entrypoint":{"treatment":"enabled","testKey":"lss-search-all-employee-new-entrypoint","trackingInfo":{"experimentId":1897833,"segmentIndex":0,"treatmentIndex":1,"urn":"urn:li:member:33699"}},"lss-out-of-inbox-overlay":{"treatment":"enabled","testKey":"lss-out-of-inbox-overlay","trackingInfo":null},"lss-productivity-dealspace":{"treatment":"control","testKey":"lss-productivity-dealspace","trackingInfo":null},"lss-crm-writeback-presentation-view":{"treatment":"enabled","testKey":"lss-crm-writeback-presentation-view","trackingInfo":null},"lss-account-center":{"treatment":"control","testKey":"lss-account-center","trackingInfo":null},"lss-user-completion-meter":{"treatment":"control","testKey":"lss-user-completion-meter","trackingInfo":null},"lss-company-orion":{"treatment":"enabled","testKey":"lss-company-orion","trackingInfo":null},"lss-ep-integration":{"treatment":"enabled","testKey":"lss-ep-integration","trackingInfo":null},"lss-lists-sharing":{"treatment":"control","testKey":"lss-lists-sharing","trackingInfo":null},"lss-search-exclusions":{"treatment":"control","testKey":"lss-search-exclusions","trackingInfo":null},"lss-profile-dossier":{"treatment":"enabled","testKey":"lss-profile-dossier","trackingInfo":null},"lss-notification-center":{"treatment":"enabled","testKey":"lss-notification-center","trackingInfo":null},"lss-crm-access-override":{"treatment":"control","testKey":"lss-crm-access-override","trackingInfo":null},"lss-lists-ranger":{"treatment":"enabled","testKey":"lss-lists-ranger","trackingInfo":null},"lss-keyword-typeahead":{"treatment":"control","testKey":"lss-keyword-typeahead","trackingInfo":null},"lss-search-frank":{"treatment":"enabled","testKey":"lss-searc ...
#   <meta content="false" name="isGuest"/>
#   <meta data-mode="BIGPIPE" name="renderingMode"/>
#   <meta content="5000" name="bigpipeResponseTimeout"/>
#   <meta content="false" name="bigpipeJetRethrowError"/>
#   <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
#   <script src="https://static.licdn.com/sc/h/br/4yyoezg1af51skxehch3vkxv7">
#   </script>
#   <meta content="Pmq50SbTcRWAMtgz4ioAAA==" name="treeID"/>
#   <meta content="https://static.licdn.com/sc/h/2f3rgdd5asit4ixdputoex4ny" id="artdeco/static/images/icons.svg" name="asset-url"/>
#   <style>
#    .initial-load-animation {
#         padding-top: 96px;
#         width: 200px;
#         margin: 0 auto;
#         transform: scale(1);
#         transition: transform .5s ease;
#       }
#       .salesnav-image {
#         background-image: url('https://static.licdn.com/sc/h/v4ody32j7r2zqlkj9lxg96x3');
#         height: 55px;
#         width: 55px;
#         margin: 0 auto;
#         margin-bottom: 32px;
#         transform: translate(0, 0);
#         opacity: 1;
#         transition: all .5s ease-out;
#       }
#       .loading-bar {
#         width: 130px;
#         height: 2px;
#         margin: 0 auto;
#         border-radius: 2px;
#         background-color: #CFCFCF;
#         position: relative;
#         overflow: hidden;
#         z-index: 1;
#         transform: rotateY(0);
#         transition: transform .3s ease-in;
#       }
#       .blue-bar {
#         height: 100%;
#         width: 68px;
#         position: absolute;
#         transform: translate(-34px, 0);
#         background-color: #0073B1;
#         border-radius: 2px;
#         animation: initial-loading 1.5s infinite ease;
#       }
#       @keyframes initial-loading {
#         0% {
#           transform: translate(-34px, 0);
#         }
#         50% {
#           transform: translate(96px, 0);
#         }
#         100% {
#           transform: translate(-34px, 0);
#         }
#       }
#       .boot-complete .initial-loading-state,
#       .hide-loading.initial-loading-state {
#         display: none;
#       }
#   </style>
#  </head>
#  <body class="ember-application boot-complete" data-t-link-to-event-attached="true">
#   <div class="initial-loading-state">
#    <div class="initial-load-animation">
#     <div class="salesnav-image">
#     </div>
#     <div class="loading-bar">
#      <div class="blue-bar">
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="https://static.licdn.com/sc/h/br/6qjcol3jb266h9q677d2lddco">
#   </script>
#   <script src="https://static.licdn.com/sc/h/br/8lsr6z12tukwkv9jhoec1neq2">
#   </script>
#   <script src="https://static.licdn.com/sc/h/br/edhquvkizf3gknkds2eot3ltw">
#   </script>
#   <div id="ember-basic-dropdown-wormhole">
#   </div>
#   <div id="artdeco-modal-outlet">
#   </div>
#   <code id="bpr-guid-5278503" style="display: none">
#    {"primaryIdentity":"dXJuOmxpOm1lbWJlcjozMzY5OQ"}
#   </code>
#   <code id="datalet-bpr-guid-5278503" style="display: none">
#    {"request":"/sales-api/salesApiPrimaryIdentity","status":200,"body":"bpr-guid-5278503"}
#   </code>
#   <img class="datalet-bpr-guid-5278503" src="..." style="display: none"/>
#   <code id="bpr-guid-5278505" style="display: none">
#    {"statuses":{},"results":{"profile-decoration.fetch.sales.navigator.info.for.contract":{"value":"enable"},"lss-ads-integration":{"value":"control"},"lss-crm-dynamics":{"value":"enabled"},"lss-crm-sync-error-handling":{"value":"enabled"},"lss-crm-writeback-presentation-view":{"value":"enabled"},"lss-account-center":{"value":"control"},"lss-crm-data-validation":{"value":"control"}},"errors":{}}
#   </code>
#   <code id="datalet-bpr-guid-5278505" style="display: none">
#    {"request":"/sales-api/salesApiTreatment?ids\u003DList(lss-account-center,lss-ads-integration,lss-crm-data-validation,lss-crm-dynamics,lss-crm-writeback-presentation-view,lss-crm-sync-error-handling,profile-decoration.fetch.sales.navigator.info.for.contract)","status":200,"body":"bpr-guid-5278505"}
#   </code>
#   <img class="datalet-bpr-guid-5278505" src="..." style="display: none"/>
#   <code id="bpr-guid-5278509" style="display: none">
#    {"onboarded":true,"salesMailboxCount":0,"seatRoles":["LSS_ADMIN_SEAT","SALES_SEAT_TIER2"],"adminCrmSynced":false,"viewerSalesUrn":"urn:li:fs_sales:(33699,313388107,91634207)","unreadMessagesCount":0,"unseenNotificationsCount":0,"viewerPrivacy":{"salesProfileViewingPrivacy":"ANONYMOUS"},"admin":true,"savedSearchesNewHitCount":284,"showAdminSettings":true,"memberResolutionResult":{"firstName":"Ted","lastName":"Schwab","objectUrn":"urn:li:member:33699","entityUrn":"urn:li:fs_salesProfile:(ACwAAAAAg6MBaB9oOxEafNtg7Zv16xXOkRwqa1I, , )","fullName":"Ted Schwab","profilePictureDisplayImage":{"artifacts":[{"width":100,"fileIdentifyingUrlPathSegment":"https://media.licdn.com/dms/image/C4E03AQHxKY31DSL3pQ/profile-displayphoto-shrink_100_100/0?e=1550707200&amp;v=beta&amp;t=L76z9PMdvBZiq5JuhGSNSmtKC5J1BFIX72yIF3_P-Lc","height":100},{"width":200,"fileIdentifyingUrlPathSegment":"https://media.licdn.com/dms/image/C4E03AQHxKY31DSL3pQ/profile-displayphoto-shrink_200_200/0?e=1550707200&amp;v=beta&amp;t=qfd3yrPNcqxoowvk8eMYA5aUYQgjcquZR-Tp2BctyT0","height":200},{"width":400,"fileIdentifyingUrlPathSegment":"https://media.licdn.com/dms/image/C4E03AQHxKY31DSL3pQ/profile-displayphoto-shrink_400_400/0?e=1550707200&amp;v=beta&amp;t=Yeu4ojveb1GZrDBM0z_QptcTK_qUkVm2Jo-phg07E4Q","height":400},{"width":800,"fileIdentifyingUrlPathSegment":"https://media.licdn.com/dms/image/C4E03AQHxKY31DSL3pQ/profile-displayphoto-shrink_800_800/0?e=1550707200&amp;v=beta&amp;t=loexhVeWbLaE2me-1uhwfVsxRd_zQsaPQqKW6T58WxI","height":800}],"rootUrl":""},"pictureInfo":{},"headline":"Founding Partner, Managing Director, and Wealth Manager, Steward Partners Global Advisory"},"adminOnly":false,"showUsageReporting":true,"seatSources":[],"linkedInMailboxCount":0,"member":"urn:li:fs_salesProfile:(ACwAAAAAg6MBaB9oOxEafNtg7Zv16xXOkRwqa1I, , )","showSettings":true,"showDealbook":false,"baseMprUrl":"https://media.licdn.com/mpr/mpr","showSeatManagement":true}
#   </code>
#   <code id="datalet-bpr-guid-5278509" style="display: none">
#    {"request":"/sales-api/salesApiNavChrome?decoration\u003D%28baseMprUrl%2CviewerPrivacy%2CviewerSalesUrn%2Cadmin%2CadminOnly%2CadminCrmSynced%2CshowAdminSettings%2CshowDealbook%2CshowSeatManagement%2CshowSettings%2CshowUsageReporting%2CunreadMessagesCount%2CsalesMailboxCount%2ClinkedInMailboxCount%2CunseenNotificationsCount%2CsavedSearchesNewHitCount%2Conboarded%2Cmember~fs_salesProfile%28entityUrn%2CfirstName%2ClastName%2CfullName%2Cheadline%2CprofilePictureDisplayImage%2CpictureInfo%28croppedImage%29%2CobjectUrn%29%2CseatSources*%2CseatRoles*%2CepAccountId%2CepApplicationInstanceId%29","status":200,"body":"bpr-guid-5278509"}
#   </code>
#   <img class="datalet-bpr-guid-5278509" src="..." style="display: none"/>
#   <code id="bpr-guid-5278537" style="display: none">
#    {"metadata":{"decoratedSpotlights":{"all":606,"mentionedInNews":15,"recentPositionChange":36,"recentPostedOnLinkedIn":165,"selectedType":"ALL","orderedSpotlights":[{"count":606,"type":"ALL"},{"count":36,"type":"RECENT_POSITION_CHANGE"},{"count":14,"type":"TEAMLINK_INTRO"},{"count":15,"type":"MENTIONED_IN_THE_NEWS"},{"count":165,"type":"RECENTLY_POSTED_ON_LINKEDIN"},{"count":285,"type":"COMMONALITIES"}],"commonalities":285,"teamlinkIntro":14},"savedSearchName":"Cyber CEO ","decoratedFilters":{"postKeywords":{},"lastName":{},"keywords":{"value":"cyber"},"excludeContacted":{"selected":false},"seniorityLevel":{"decoratedValues":[{"excluded":false,"decoratedValue":"CXO","count":589,"id":"8","selected":false},{"excluded":false,"decoratedValue":"Senior","count":279,"id":"4","selected":false},{"excluded":false,"decoratedValue":"Owner","count":199,"id":"10","selected":false},{"excluded":false,"decoratedValue":"Partner","count":130,"id":"9","selected":false},{"excluded":false,"decoratedValue":"Entry","count":114,"id":"3","selected":false},{"excluded":false,"decoratedValue":"Director","count":100,"id":"6","selected":false},{"excluded":false,"decoratedValue":"VP","count":58,"id":"7","selected":false},{"excluded":false,"decoratedValue":"Manager","count":37,"id":"5","selected":false},{"excluded":false,"decoratedValue":"Training","count":6,"id":"2","selected":false},{"excluded":false,"decoratedValue":"Unpaid","count":4,"id":"1","selected":false}]},"industry":{"decoratedValues":[{"excluded":false,"decoratedValue":"Information Technology and Services","count":219,"id":"96","selected":false},{"excluded":false,"decoratedValue":"Computer &amp; Network Security","count":72,"id":"118","selected":false},{"excluded":false,"decoratedValue":"Defense &amp; Space","count":58,"id":"1","selected":false},{"excluded":false,"decoratedValue":"Management Consulting","count":37,"id":"11","selected":false},{"excluded":false,"decoratedValue":"Computer Software","count":31,"id":"4","selected":false},{"excluded":false,"decoratedValue":"Telecommunications","count":12,"id":"8","selected":false},{"excluded":false,"decoratedValue":"International Affairs","count":10,"id":"74","selected":false},{"excluded":false,"decoratedValue":"Government Administration","count":10,"id":"75","selected":false},{"excluded":false,"decoratedValue":"Security and Investigations","count":9,"id":"121","selected":false},{"excluded":false,"decoratedValue":"Financial Services","count":9,"id":"43","selected":false},{"excluded":false,"decoratedValue":"Military","count":9,"id":"71","selected":false},{"excluded":false,"decoratedValue":"Government Relations","count":8,"id":"148","selected":false},{"excluded":false,"decoratedValue":"Venture Capital &amp; Private Equity","count":7,"id":"106","selected":false},{"excluded":false,"decoratedValue":"Internet","count":6,"id":"6","selected":false},{"excluded":false,"decoratedValue":"Research","count":6,"id":"70","selected":false}]},"excludeSaved":{"selected":false},"searchWithinMyAcct":{"selected":false},"title":{"scope":"CURRENT","values":[{"excluded":false,"text":"ceo"}]},"companySize":{"decoratedValues":[{"excluded":false,"decoratedValue":"Self-employed","count":56,"id":"A","selected":false},{"excluded":false,"decoratedValue":"1-10","count":504,"id":"B","selected":false},{"excluded":false,"decoratedValue":"11-50","count":451,"id":"C","selected":false},{"excluded":false,"decoratedValue":"51-200","count":236,"id":"D","selected":true},{"excluded":false,"decoratedValue":"201-500","count":126,"id":"E","selected":true},{"excluded":false,"decoratedValue":"501-1000","count":45,"id":"F","selected":true},{"excluded":false,"decoratedValue":"1001-5000","count":90,"id":"G","selected":true},{"excluded":false,"decoratedValue":"5001-10,000","count":55,"id":"H","selected":true},{"excluded":false,"decoratedValue":"10,000+","count":177,"id":"I","selected":true}]},"geo":{"decoratedValues":[{"excluded":false,"decoratedValue":"United States","count":3069,"id":"us:0","selected" ...
#   </code>
#   <code id="datalet-bpr-guid-5278537" style="display: none">
#    {"request":"/sales-api/salesApiPeopleSearch?q\u003DsavedSearch\u0026savedSearchId\u003D274884636\u0026newResultsOnly\u003Dfalse\u0026start\u003D0\u0026count\u003D25\u0026trackingParam\u003D(sessionId:7Jkr5RLjS66MboylCLh6Ww\u003D\u003D)","status":200,"body":"bpr-guid-5278537"}
#   </code>
#   <img class="datalet-bpr-guid-5278537" src="..." style="display: none"/>
#   <code id="bpr-guid-5278542" style="display: none">
#    {"metadata":{"decoratedSpotlights":{"all":606,"mentionedInNews":15,"recentPositionChange":36,"recentPostedOnLinkedIn":165,"selectedType":"ALL","orderedSpotlights":[{"count":606,"type":"ALL"},{"count":36,"type":"RECENT_POSITION_CHANGE"},{"count":14,"type":"TEAMLINK_INTRO"},{"count":15,"type":"MENTIONED_IN_THE_NEWS"},{"count":165,"type":"RECENTLY_POSTED_ON_LINKEDIN"},{"count":285,"type":"COMMONALITIES"}],"commonalities":285,"teamlinkIntro":14},"savedSearchName":"Cyber CEO ","decoratedFilters":{"postKeywords":{},"lastName":{},"keywords":{"value":"cyber"},"excludeContacted":{"selected":false},"seniorityLevel":{"decoratedValues":[{"excluded":false,"decoratedValue":"CXO","count":589,"id":"8","selected":false},{"excluded":false,"decoratedValue":"Senior","count":279,"id":"4","selected":false},{"excluded":false,"decoratedValue":"Owner","count":199,"id":"10","selected":false},{"excluded":false,"decoratedValue":"Partner","count":130,"id":"9","selected":false},{"excluded":false,"decoratedValue":"Entry","count":114,"id":"3","selected":false},{"excluded":false,"decoratedValue":"Director","count":100,"id":"6","selected":false},{"excluded":false,"decoratedValue":"VP","count":58,"id":"7","selected":false},{"excluded":false,"decoratedValue":"Manager","count":37,"id":"5","selected":false},{"excluded":false,"decoratedValue":"Training","count":6,"id":"2","selected":false},{"excluded":false,"decoratedValue":"Unpaid","count":4,"id":"1","selected":false}]},"industry":{"decoratedValues":[{"excluded":false,"decoratedValue":"Information Technology and Services","count":219,"id":"96","selected":false},{"excluded":false,"decoratedValue":"Computer &amp; Network Security","count":72,"id":"118","selected":false},{"excluded":false,"decoratedValue":"Defense &amp; Space","count":58,"id":"1","selected":false},{"excluded":false,"decoratedValue":"Management Consulting","count":37,"id":"11","selected":false},{"excluded":false,"decoratedValue":"Computer Software","count":31,"id":"4","selected":false},{"excluded":false,"decoratedValue":"Telecommunications","count":12,"id":"8","selected":false},{"excluded":false,"decoratedValue":"International Affairs","count":10,"id":"74","selected":false},{"excluded":false,"decoratedValue":"Government Administration","count":10,"id":"75","selected":false},{"excluded":false,"decoratedValue":"Security and Investigations","count":9,"id":"121","selected":false},{"excluded":false,"decoratedValue":"Financial Services","count":9,"id":"43","selected":false},{"excluded":false,"decoratedValue":"Military","count":9,"id":"71","selected":false},{"excluded":false,"decoratedValue":"Government Relations","count":8,"id":"148","selected":false},{"excluded":false,"decoratedValue":"Venture Capital &amp; Private Equity","count":7,"id":"106","selected":false},{"excluded":false,"decoratedValue":"Internet","count":6,"id":"6","selected":false},{"excluded":false,"decoratedValue":"Research","count":6,"id":"70","selected":false}]},"excludeSaved":{"selected":false},"searchWithinMyAcct":{"selected":false},"title":{"scope":"CURRENT","values":[{"excluded":false,"text":"ceo"}]},"companySize":{"decoratedValues":[{"excluded":false,"decoratedValue":"Self-employed","count":56,"id":"A","selected":false},{"excluded":false,"decoratedValue":"1-10","count":504,"id":"B","selected":false},{"excluded":false,"decoratedValue":"11-50","count":451,"id":"C","selected":false},{"excluded":false,"decoratedValue":"51-200","count":236,"id":"D","selected":true},{"excluded":false,"decoratedValue":"201-500","count":126,"id":"E","selected":true},{"excluded":false,"decoratedValue":"501-1000","count":45,"id":"F","selected":true},{"excluded":false,"decoratedValue":"1001-5000","count":90,"id":"G","selected":true},{"excluded":false,"decoratedValue":"5001-10,000","count":55,"id":"H","selected":true},{"excluded":false,"decoratedValue":"10,000+","count":177,"id":"I","selected":true}]},"geo":{"decoratedValues":[{"excluded":false,"decoratedValue":"United States","count":3069,"id":"us:0","selected" ...
#   </code>
#   <code id="datalet-bpr-guid-5278542" style="display: none">
#    {"request":"/sales-api/salesApiPeopleSearch?q\u003DsavedSearch\u0026savedSearchId\u003D274884636\u0026newResultsOnly\u003Dfalse\u0026start\u003D0\u0026count\u003D25\u0026trackingParam\u003D(sessionId:7Jkr5RLjS66MboylCLh6Ww\u003D\u003D)","status":200,"body":"bpr-guid-5278542"}
#   </code>
#   <img class="datalet-bpr-guid-5278542" src="..." style="display: none"/>
#   <code id="clientPageInstance" style="display: none">
#    urn:li:page:d_sales2_search_people_saved_all;LIJmmYwsT9y7e2A9HV371A==
#   </code>
#   <img class="terminatorlet" src="..." style="display: none"/>
#   <div class="ember-view" id="ember3">
#    <!-- -->
#    <header class="global-nav global-nav-v2 ember-view" id="ember4">
#     <div class="navbar-main">
#      <div class="container">
#       <h1 class="brand">
#        <a href="/sales?trk=d_sales2_nav_snlogo">
#         <linkedin-logo class="ember-view" id="ember7" size="28dp">
#          <li-icon aria-hidden="true" class="logo-lockup-inverse" color="inverse" size="28dp" type="linkedin-bug">
#           <svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg">
#            <g class="scaling-icon" style="fill-opacity: 1">
#             <defs>
#             </defs>
#             <g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#              <g class="dp-1">
#               <path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF">
#               </path>
#               <path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2">
#               </path>
#              </g>
#              <g class="dpi-gt1" transform="scale(0.2917)">
#               <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#               </rect>
#               <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#               </path>
#              </g>
#             </g>
#             <g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#              <g class="dp-1">
#               <path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF">
#               </path>
#               <path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5">
#               </path>
#              </g>
#              <g class="dpi-gt1" transform="scale(0.4375)">
#               <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#               </rect>
#               <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#               </path>
#              </g>
#             </g>
#             <g class="bug-28dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#              <g class="dp-1">
#               <path class="bug-text-color" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0" fill="#FFFFFF">
#               </path>
#               <path class="background" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0 Z M14.8747,12.025 L14.8747,10 L10.9997,10 L10.9997,24 L14.9997,24 L14.9997,17.375 C14.9997,15.603 15.6627,13.875 17.6497,13.875 C19.4667,13.875 19.9997,14.965 19.9997,16.875 L19.9997,24 L23.9997,24 L23.9997,14.975 C23.9997,11.75 22.2917,9.875 19.0137,9.875 C16.9227,9.875 15.4487,11.025 14.8747,12.025 Z M4,24 L8,24 L8,10 L4,10 L4,24 Z M6,3.665 C4.71,3.665 3.665,4.71 3.665,6 C3.665,7.29 4.71,8.335 6,8.335 C7.29,8.335 8.335,7.29 8.335,6 C8.335,4.71 7.29,3.665 6,3.665 Z" fill="#0077B5">
#               </path>
#              </g>
#              <g class="dpi-gt1" transform="scale(0.5833)">
#               <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#               </rect>
#               <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#               </path>
#              </g>
#             </g>
#             <g class="bug-34dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#              <g class="dp-1">
#               <path class="bug-text-color" d="M2.8,34 L31.2,34 C32.746,34 34,32.746 34,31.2 L34,2.8 C34,1.254 32.746,0 31.2,0 L2.8,0 C1.254,0 0,1.254 0,2.8 L0,31.2 C0,32.746 1.254,34 2.8,34" fill="#FFFFFF">
#               </path>
#               <path class="background" d="M2.8,34 L31.2,34 C32.746,34 34,32.746 34,31.2 L34,2.8 C34,1.254 32.746,0 31.2,0 L2.8,0 C1.254,0 0,1.254 0,2.8 L0,31.2 C0,32.746 1.254,34 2.8,34 Z M13,13 L17.75,13 L17.75,15.391 C18.387,14.114 20.242,12.75 22.695,12.75 C27.397,12.75 29,14.875 29,19.922 L29,29 L24,29 L24,20.984 C24,18.328 23.481,16.875 21.542,16.875 C18.921,16.875 18,18.867 18,20.984 L18,29 L13,29 L13,13 Z M5,29 L10,29 L10,13 L5,13 L5,29 Z M10.55,7.5 C10.55,9.184 9.184,10.55 7.5,10.55 C5.816,10.55 4.45,9.184 4.45,7.5 C4.45,5.815 5.816,4.45 7.5,4.45 C9.184,4.45 10.55,5.815 10.55,7.5 Z" fill="#0077B5">
#               </path>
#              </g>
#              <g class="dpi-gt1" transform="scale(0.7083)">
#               <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#               </rect>
#               <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#               </path>
#              </g>
#             </g>
#             <g class="bug-40dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#              <g class="dp-1">
#               <path class="bug-text-color" d="M40,3.5 L40,36.5 C40,38.434 38.434,40 36.5,40 L3.5,40 C1.566,40 0,38.434 0,36.5 L0,3.5 C0,1.566 1.566,0 3.5,0 L36.5,0 C38.434,0 40,1.566 40,3.5 L40,3.5 Z" fill="#FFFFFF">
#               </path>
#               <path class="background" d="M40,3.5 L40,36.5 C40,38.434 38.434,40 36.5,40 L3.5,40 C1.566,40 0,38.434 0,36.5 L0,3.5 C0,1.566 1.566,0 3.5,0 L36.5,0 C38.434,0 40,1.566 40,3.5 Z M15,15.0000122 L20.875,15.0000122 L20.875,18.3330122 C21.542,17.1460122 23,14.7000122 26.957,14.7000122 C33.137,14.7000122 34,18.6800122 34,23.9670122 L34,34.0000122 L28,34.0000122 L28,25.0180122 C28,22.1830122 27.542,19.8750122 24.922,19.8750122 C21.75,19.8750122 21,21.9560122 21,24.5160122 L21,34.0000122 L15,34.0000122 L15,15.0000122 Z M6,34 L12,34 L12,15 L6,15 L6,34 Z M12.6509756,8.99997559 C12.6509756,11.0159756 11.0169756,12.6499756 9.00097559,12.6499756 C6.98397559,12.6499756 5.34997559,11.0159756 5.34997559,8.99997559 C5.34997559,6.98397559 6.98397559,5.34997559 9.00097559,5.34997559 C11.0169756,5.34997559 12.6509756,6.98397559 12.6509756,8.99997559 Z" fill="#0077B5">
#               </path>
#              </g>
#              <g class="dpi-gt1" transform="scale(0.8333)">
#               <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#               </rect>
#               <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#               </path>
#              </g>
#             </g>
#             <g class="bug-48dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#              <rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1">
#              </rect>
#              <path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5">
#              </path>
#             </g>
#            </g>
#           </svg>
#          </li-icon>
#          <span class="logo-text logo-lockup-inverse">
#           Sales Navigator
#          </span>
#         </linkedin-logo>
#        </a>
#       </h1>
#       <nav class="nav-main">
#        <ul>
#         <li class="nav-item nav-item-home">
#          <a class="nav-item__text" href="/sales/?trk=d_sales2_nav_home">
#           Home
#          </a>
#         </li>
#         <!-- -->
#         <li class="nav-item nav-item-lists">
#          <h2 class="nav-item__text">
#           Lists
#          </h2>
#          <div class="dropdown-menu nav-item__dropdown-menu">
#           <ul class="list-menu">
#            <li>
#             <a class="ember-view" href="/sales/search/people/list/my-network" id="ember8">
#              My network
#             </a>
#            </li>
#            <li class="list-menu__profile-item">
#             <a class="ember-view" data-control-name="view_lead_lists_from_nav" href="/sales/lists/people" id="ember9">
#              Lead Lists
#             </a>
#            </li>
#            <li class="list-menu__account-item">
#             <a class="ember-view" data-control-name="view_account_lists_from_nav" href="/sales/lists/company" id="ember10">
#              Account Lists
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="nav-item nav-item-discover">
#          <h2 class="nav-item__text">
#           Discover
#          </h2>
#          <div class="dropdown-menu nav-item__dropdown-menu">
#           <ul>
#            <li>
#             <a class="ember-view" href="/sales/search/people/list/recommended-leads" id="ember11">
#              Recommended leads
#             </a>
#            </li>
#            <li>
#             <a class="ember-view" href="/sales/search/company/list/recommended-accounts" id="ember12">
#              Recommended accounts
#             </a>
#            </li>
#            <li>
#             <a href="/sales/settings?trk=d_sales2_nav_discover">
#              Edit your sales preferences
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="nav-item nav-item-admin">
#          <h2 class="nav-item__text">
#           Admin
#          </h2>
#          <div class="dropdown-menu nav-item__dropdown-menu">
#           <ul>
#            <li>
#             <a href="/sales/usageReport?trk=d_sales2_nav_admin">
#              Usage Reporting
#             </a>
#            </li>
#            <li>
#             <div class="ember-view" id="ember13">
#              <a href="/sales/admin/seats?trk=d_sales2_nav_admin">
#               Seat Management
#              </a>
#             </div>
#            </li>
#            <li>
#             <a class="ember-view" href="/sales/admin/settings?trk=d_sales2_nav_admin" id="ember14">
#              Admin Settings
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#        </ul>
#       </nav>
#       <nav class="utility-navs">
#        <ul>
#         <li class="nav-item nav-item-inbox">
#          <a class="nav-item__text type--icon ember-view" href="/sales/inbox?trk=d_sales2_nav_inbox" id="ember15">
#           <li-icon aria-label="Inbox" class="nav-item__icon" role="img" type="messages-icon">
#            <svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#             <path class="large-icon" d="M21,8H8A1,1,0,0,0,7,9V19a1,1,0,0,0,1,1H18l4,3V9A1,1,0,0,0,21,8ZM20,19.11L18.52,18H9V10H20v9.11ZM12,15h5v1H12V15ZM4,13H5v2H3a1,1,0,0,1-1-1V4A1,1,0,0,1,3,3H16a1,1,0,0,1,1,1V6H15V5H4v8Zm14,0H11V12h7v1Z" style="fill: currentColor">
#             </path>
#            </svg>
#           </li-icon>
#           <!-- -->
#          </a>
#          <div class="dropdown nav-item__dropdown">
#           <ul>
#            <li>
#             <a class="ember-view" href="/sales/inbox?trk=d_sales2_nav_inbox" id="ember16">
#              Sales Navigator Inbox
#             </a>
#            </li>
#            <li>
#             <a href="/messaging?trk=d_sales2_nav_inbox" rel="noopener noreferrer" target="_blank">
#              LinkedIn Inbox
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="alert-center nav-item type--icon nav-item-alert-center ember-view" id="ember17">
#          <button class="button--unstyled nav-item__text type--icon" data-ember-action="" data-ember-action-18="18" type="button">
#           <li-icon aria-label="Alerts" class="nav-item__icon" role="img" type="bell-filled-icon">
#            <svg focusable="false" height="24" preserveaspectratio="xMinYMin meet" style="" viewbox="0 0 24 24" width="24" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#             <path class="large-icon" d="M18.94,14H5.06L5.79,8.44A6.26,6.26,0,0,1,12,3h0a6.26,6.26,0,0,1,6.21,5.44Zm2,5-1.71-4H4.78L3.06,19a0.71,0.71,0,0,0-.06.28,0.75,0.75,0,0,0,.75.76H10a2,2,0,1,0,4,0h6.27A0.74,0.74,0,0,0,20.94,19Z" style="fill: currentColor">
#             </path>
#            </svg>
#           </li-icon>
#          </button>
#          <!-- -->
#          <!-- -->
#         </li>
#         <li class="nav-item nav-item-user">
#          <h2 class="nav-item__text type--entity">
#           <span class="a11y-text">
#            Ted Schwab
#           </span>
#           <img alt="" class="entity-person" src="https://media.licdn.com/dms/image/C4E03AQHxKY31DSL3pQ/profile-displayphoto-shrink_800_800/0?e=1550707200&amp;v=beta&amp;t=loexhVeWbLaE2me-1uhwfVsxRd_zQsaPQqKW6T58WxI"/>
#           <!-- -->
#           <div id="profile-visibility-settings-wormhole">
#           </div>
#          </h2>
#          <div class="dropdown nav-item__dropdown">
#           <h3>
#            Account
#           </h3>
#           <ul class="utility-nav-items" role="navigation">
#            <li class="settings">
#             <a href="/sales/settings?trk=d_sales2_nav_account">
#              Settings
#             </a>
#            </li>
#            <li class="user-agreement">
#             <a href="/legal/user-agreement?trk=d_sales2_nav_account" rel="noopener noreferrer" target="_blank">
#              User agreement
#             </a>
#            </li>
#            <li class="privacy-policy">
#             <a href="/legal/privacy-policy?trk=d_sales2_nav_account" rel="noopener noreferrer" target="_blank">
#              Privacy policy
#             </a>
#            </li>
#            <li class="cookie-policy">
#             <a href="/legal/cookie-policy?trk=d_sales2_nav_account" rel="noopener noreferrer" target="_blank">
#              Cookie policy
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Help
#           </h3>
#           <ul>
#            <li class="learning-center">
#             <a href="/sales/training?trk=d_sales2_nav_account" rel="noopener noreferrer" target="_blank">
#              Learning Center
#             </a>
#            </li>
#            <li class="help-center">
#             <a href="/help/sales-navigator?trk=d_sales2_nav_account" rel="noopener noreferrer" target="_blank">
#              Help Center
#             </a>
#            </li>
#           </ul>
#           <hr/>
#           <h3 class="a11y-text">
#            Other
#           </h3>
#           <ul>
#            <li class="user">
#             <a href="/sales/logout?trk=d_sales2_nav_account">
#              Sign out
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <hr class="nav-divider"/>
#         <li class="nav-item nav-item-pointdrive-link" id="nav-item-pointdrive">
#          <artdeco-hoverable-trigger class="nav-pointdrive-logo-tooltip-trigger ember-view" id="ember642" tabindex="-1">
#           <a aria-describedby="artdeco-hoverable-artdeco-gen-55" class="nav-item__text type--icon" href="/sales/presentationAccess?trk=d_sales2_nav_pdlogo" rel="noopener noreferrer" target="_blank">
#            <span class="a11y-text">
#             Go to PointDrive
#            </span>
#            <li-icon aria-hidden="true" class="nav-item__icon" type="nav-small-pointdrive-inverse-icon">
#             <svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#              <g class="" style="fill-opacity: 1">
#               <path d="M12,5A4,4,0,0,0,8,9h8A4,4,0,0,0,12,5Z" style="fill: #fff;opacity: 0.85">
#               </path>
#               <path d="M2,9V23A7,7,0,0,0,2,9Z" style="fill: #fff">
#               </path>
#               <path d="M21,1H3A1,1,0,0,0,2,2V9a7,7,0,0,1,3.59,1H20v9H8.32a7,7,0,0,1-1.42,2H21a1,1,0,0,0,1-1V2A1,1,0,0,0,21,1ZM20,9H4V3H20V9Z" style="fill: #fff;opacity: 0.7">
#               </path>
#               <path d="M9,16a7,7,0,0,1-.08,1H16V16H9Z" style="fill: #fff;opacity: 0.7">
#               </path>
#               <path d="M8.32,13a7,7,0,0,1,.39,1H18V13H8.32Z" style="fill: #fff;opacity: 0.7">
#               </path>
#              </g>
#             </svg>
#            </li-icon>
#           </a>
#           <div class="pointdrive-icon-tooltip-content nav-item__tooltip ember-view" id="artdeco-gen-55" style="display: none;" theme="inverse">
#            <div class="ember-view" id="ember644">
#            </div>
#           </div>
#          </artdeco-hoverable-trigger>
#          <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-55" role="tooltip" tabindex="-1" theme="inverse">
#           <div class="artdeco-tooltip-content-container">
#            Go to PointDrive
#           </div>
#           <!-- -->
#          </artdeco-tooltip-content>
#         </li>
#         <li class="nav-item nav-item-app-switcher">
#          <h2 class="nav-item__text type--icon" title="More products">
#           <li-icon aria-label="More products" class="nav-item__icon" role="img" type="grid-icon">
#            <svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#             <path class="large-icon" d="M10,10h4v4H10V10Zm0,11h4V17H10v4ZM3,14H7V10H3v4Zm0,7H7V17H3v4ZM3,7H7V3H3V7Zm14,7h4V10H17v4ZM17,3V7h4V3H17ZM10,7h4V3H10V7Zm7,14h4V17H17v4Z" style="fill: currentColor">
#             </path>
#            </svg>
#           </li-icon>
#          </h2>
#          <div class="dropdown nav-item__dropdown">
#           <h3>
#            Visit more LinkedIn products
#           </h3>
#           <ul>
#            <li>
#             <a href="/?trk=d_sales2_nav_applauncher">
#              <span class="product-logo">
#               <li-icon aria-hidden="true" type="app-linkedin-bug-color-icon">
#                <svg focusable="false" height="40px" preserveaspectratio="xMinYMin meet" viewbox="0 0 40 40" width="40px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#                 <g class="app-icon" style="fill: currentColor">
#                  <g>
#                   <path d="M34.5,3H5.6C4.2,3,3,4.1,3,5.4v29.1C3,35.9,4.2,37,5.6,37h29C35.9,37,37,35.9,37,34.6V5.4C37,4.1,35.9,3,34.5,3z" style="fill:#0077B5;">
#                   </path>
# ...
#                 </h4>
#                 <dl class="result-context__summary-list mt2">
#                  <dt class="result-context__summary-term Sans-12px-black-60%-bold">
#                   Past role
#                  </dt>
#                  <dd class="Sans-14px-black-75%">
#                   <span>
#                    EVP/ Global Chief Information Officer
#                   </span>
#                   at
#                   <span data-entity-hovercard-id="urn:li:fs_salesCompany:1760">
#                    <a class="Sans-14px-black-75%-bold ember-view" href="/sales/company/1760" id="ember577">
#                     AIG
#                    </a>
#                   </span>
#                   <span class="result-context__employment-range">
#                    (2014 - 2017)
#                   </span>
#                  </dd>
#                  <!-- -->
#                  <!-- -->
#                 </dl>
#                 <!-- -->
#                 <div class="ember-view" id="ember578">
#                  <div class="result-content__connection-items flex">
#                   <!-- -->
#                   <div class="result-context__connection-summary relative flex flex-grow-1 align-items-center pv0 ">
#                    <div class="result-context__facepile-container mr2">
#                     <img alt="" class="lazy-image result-context__connection-facepile"/>
#                     <img alt="" class="lazy-image result-context__connection-facepile"/>
#                     <img alt="" class="lazy-image result-context__connection-facepile"/>
#                    </div>
#                    <ul class="result-context__connection-toggles p0 relative flex list-style-none align-items-center">
#                     <li>
#                      <button class="type-shared_connections result-context__connection-button button--unstyled Sans-12px-black-60%-bold " data-ember-action="" data-ember-action-583="583" role="button">
#                       7 shared connections
#                      </button>
#                     </li>
#                     <!-- -->
#                    </ul>
#                   </div>
#                  </div>
#                  <!-- -->
#                 </div>
#                </section>
#               </article>
#              </div>
#             </div>
#            </div>
#           </li>
#           <div class="deferred-area deferred-area--pending ember-view" id="ember584" style="min-height: 600px">
#            <li-icon aria-hidden="true" class="deferred-area__loader" size="large" type="loader">
#             <div class="artdeco-spinner">
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#              <span class="artdeco-spinner-bars">
#              </span>
#             </div>
#            </li-icon>
#           </div>
#          </ol>
#         </form>
#        </div>
#        <div class="relative search-filter ember-view" data-test-filter-code="PAGE" id="ember585">
#         <nav aria-label="Search result pagination navigation" class="search-results__pagination display-flex align-items-center" role="navigation">
#          <button class="search-results__pagination-previous-button" data-ember-action="" data-ember-action-586="586" disabled="" tabindex="0" type="button">
#           <li-icon aria-hidden="true" class="v-align-middle" size="small" type="chevron-left-icon">
#            <svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#             <path class="small-icon" d="M7,8l4,5.9L9.5,15,5.3,8.8a1.22,1.22,0,0,1,0-1.6L9.5,1,11,2.1Z" style="fill-opacity: 1">
#             </path>
#            </svg>
#           </li-icon>
#           <span class="v-align-middle">
#            Previous
#           </span>
#          </button>
#          <ol class="search-results__pagination-list">
#           <li aria-current="true" aria-label="Current page (page 1)" class="selected cursor-pointer">
#            1
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 2" data-ember-action="" data-ember-action-587="587" data-page-number="2" role="link">
#             2
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 3" data-ember-action="" data-ember-action-588="588" data-page-number="3" role="link">
#             3
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 4" data-ember-action="" data-ember-action-589="589" data-page-number="4" role="link">
#             4
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 5" data-ember-action="" data-ember-action-590="590" data-page-number="5" role="link">
#             5
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 6" data-ember-action="" data-ember-action-591="591" data-page-number="6" role="link">
#             6
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 7" data-ember-action="" data-ember-action-592="592" data-page-number="7" role="link">
#             7
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 8" data-ember-action="" data-ember-action-593="593" data-page-number="8" role="link">
#             8
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 9" data-ember-action="" data-ember-action-594="594" data-page-number="9" role="link">
#             9
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <!-- -->
#            <a aria-label="Navigate to page 10" data-ember-action="" data-ember-action-595="595" data-page-number="10" role="link">
#             10
#            </a>
#            <!-- -->
#           </li>
#           <li class="cursor-pointer" tabindex="0">
#            <span class="search-results__pagination-ellipsis">
#             …
#            </span>
#            <a aria-label="Navigate to page 25" data-ember-action="" data-ember-action-597="597" data-page-number="25" role="link">
#             25
#            </a>
#            <!-- -->
#           </li>
#          </ol>
#          <button class="search-results__pagination-next-button" data-ember-action="" data-ember-action-598="598" tabindex="0" type="button">
#           <span class="v-align-middle">
#            Next
#           </span>
#           <li-icon aria-hidden="true" class="v-align-middle" size="small" type="chevron-right-icon">
#            <svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0">
#             <path class="small-icon" d="M9,8L5,2.07,6.54,1l4.2,6.15a1.5,1.5,0,0,1,0,1.69L6.54,15,5,13.93Z" style="fill-opacity: 1">
#             </path>
#            </svg>
#           </li-icon>
#          </button>
#         </nav>
#        </div>
#       </section>
#      </div>
#     </div>
#     <div class="ember-view" id="ember599">
#      <!-- -->
#     </div>
#     <div class="ember-view" id="ember600">
#      <!-- -->
#     </div>
#    </main>
#    <div class="msg-overlay-container ember-view" id="ember601">
#     <!-- -->
#     <div class="ember-view" id="ember602">
#      <!-- -->
#     </div>
#    </div>
#    <!-- -->
#    <artdeco-toasts class="artdeco-toasts ember-view" id="artdeco-toasts-outlet">
#     <div class="ember-view" id="ember604">
#      <ul class="artdeco-toasts-container" data-ember-action="" data-ember-action-605="605" data-ember-action-606="606">
#       <!-- -->
#      </ul>
#     </div>
#    </artdeco-toasts>
#    <div class="magic-popup carousels-hovercard" id="carousels-hovercard">
#    </div>
#    <div class="magic-popup tags-notes-popup" id="tags-notes-popup">
#    </div>
#    <div class="magic-popup notes-popup" id="notes-popup">
#    </div>
#    <div id="ui-modal-outlet">
#    </div>
#    <div id="artdeco-hoverable-outlet">
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-42" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-43" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Open Profile
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This Premium feature allows anyone on LinkedIn to contact you directly for free, even if they are not connected with you.
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-44" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-45" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Open Profile
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This Premium feature allows anyone on LinkedIn to contact you directly for free, even if they are not connected with you.
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-46" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-47" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Open Profile
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This Premium feature allows anyone on LinkedIn to contact you directly for free, even if they are not connected with you.
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-48" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-49" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-50" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Open Profile
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This Premium feature allows anyone on LinkedIn to contact you directly for free, even if they are not connected with you.
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-51" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-52" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Open Profile
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This Premium feature allows anyone on LinkedIn to contact you directly for free, even if they are not connected with you.
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-53" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Premium Member
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This is a LinkedIn Premium member
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#     <artdeco-tooltip-content aria-hidden="true" class=" " id="artdeco-hoverable-artdeco-gen-54" role="tooltip" tabindex="-1" theme="inverse">
#      <div class="artdeco-tooltip-content-container">
#       <aside>
#        <h3 class="Sans-12px-black-90%-bold pv2">
#         Open Profile
#        </h3>
#        <p class="Sans-12px-black-90%">
#         This Premium feature allows anyone on LinkedIn to contact you directly for free, even if they are not connected with you.
#        </p>
#       </aside>
#      </div>
#      <!-- -->
#     </artdeco-tooltip-content>
#    </div>
#    <div class="alerts-hoverable-outlet" id="alerts-hoverable-outlet">
#    </div>
#    <div class="entity-hovercard-container hidden ember-view" id="ember607">
#     <div class="entity-hovercard " role="tooltip" tabindex="-1">
#      <section class="entity-hovercard__loading-state p4">
#       Loading…
#      </section>
#     </div>
#    </div>
#    <div class="ember-view" id="ember608">
#     <!-- -->
#    </div>
#   </div>
#  </body>
# </html>

# %%
name =  soup.findAll('h3')
#company = soup.find('div', class_='article_teaser_body').text

print(name)
#print(company)
# Out:
# [<h3>
#                 Account
#               </h3>, <h3>
#                 Help
#               </h3>, <h3 class="a11y-text">
#                 Other
#               </h3>, <h3>
#               Visit more LinkedIn products
#             </h3>, <h3 class="dropdown-heading">
#             Saved Searches
#             –
#             <button class="trigger-saved-searches" data-ember-action="" data-ember-action-27="27">
#               Edit
#             </button>
# </h3>, <h3 class="hide-a11y">Help links</h3>, <h3 class="a11y-text">
#       Profile result - Rob Rosenberger
#     </h3>, <h3 class="a11y-text">
#       Profile result - Igor Volovich
#     </h3>, <h3 class="a11y-text">
#       Profile result - EDWARD P. GIBSON
#     </h3>, <h3 class="a11y-text">
#       Profile result - Richard Spires
#     </h3>, <h3 class="a11y-text">
#       Profile result - Dave Merkel
#     </h3>, <h3 class="a11y-text">
#       Profile result - Tim Reardon
#     </h3>, <h3 class="a11y-text">
#       Profile result - Rich Carlson
#     </h3>, <h3 class="a11y-text">
#       Profile result - Chris Coleman
#     </h3>, <h3 class="a11y-text">
#       Profile result - Tien Wong
#     </h3>, <h3 class="a11y-text">
#       Profile result - Phil Fasano
#     </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Open Profile
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Open Profile
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Open Profile
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Open Profile
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Open Profile
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Premium Member
#                   </h3>, <h3 class="Sans-12px-black-90%-bold pv2">
#                     Open Profile
#                   </h3>]
